# %% [markdown]
# # 5. Data Analysis: Waiting Time Model and Visualization of Crimes on Map
# - The following Jupyter Notebook takes the cleaned data sets **same_day_emails.csv** and **crimes_final_dataframe_part1.csv** and has a few visualizations that provide some more insight about where crimes occur more frequently, and a potential trend in the waiting time for a WarnMe email to be sent out since the crime occurrence (for same day emails)

# %%
import folium as fol
from folium.plugins import HeatMap
import pandas as pd
import matplotlib as plot

import numpy as np
import seaborn as sns

# %%
same_day_emails_df = pd.read_csv('same_day_emails.csv').drop(['Unnamed: 0'], axis=1)
crimes_final_df = pd.read_csv('crimes_final_dataframe_part1.csv').drop(['Unnamed: 0'], axis=1)
same_day_emails_df
# Out:
#                                                Subject  \
# 0         Burglary at University Village: Albany (UVA)
# 1    Arson Reported at 2650 Haste St., Berkeley CA ...
# 2    Violent Crime Reported at 3100 Block of Dwight...
# 3    Violent Crime Reported at Channing Way/ Colleg...
# 4            Burglary at Clark Kerr Campus building 23
# ..                                                 ...
# 141  Sproul Plaza -  Violent Crime Reported - Pleas...
# 142                     Burglary at 1050 San Pablo Ave
# 143  Stuart Street & Hillegas Ave -  Violent Crime ...
# 144  Singletrack trail east of the Botanical Garden...
# 145           Burglary at Richmond Field Station (RFS)
#
#                                                   Body date of crime  \
# 0     <https://oem.berkeley.edu/sites/default/files...    06-17-2021
# 1     <https://oem.berkeley.edu/sites/default/files...    06-16-2021
# 2     <https://oem.berkeley.edu/sites/default/files...    06-08-2021
# 3     <https://oem.berkeley.edu/sites/default/files...    05-18-2021
# 4     <https://oem.berkeley.edu/sites/default/files...    07-01-2021
# ..                                                 ...           ...
# 141   <https://oem.berkeley.edu/sites/default/files...    10-25-2023
# 142   <https://oem.berkeley.edu/sites/default/files...    09-21-2023
# 143   <https://oem.berkeley.edu/sites/default/files...    09-07-2023
# 144   <https://oem.berkeley.edu/sites/default/files...    08-20-2023
# 145   <https://oem.berkeley.edu/sites/default/files...    06-07-2023
#
#     time of crime email time email day of week  email date  \
# 0           02:09      04:02          Thursday  06-17-2021
# 1           05:20      10:10         Wednesday  06-16-2021
# 2           13:15      16:51           Tuesday  06-08-2021
# 3           15:50      23:23           Tuesday  05-18-2021
# 4           18:07      19:32          Thursday  07-01-2021
# ..            ...        ...               ...         ...
# 141         13:30      14:14         Wednesday  10-25-2023
# 142         11:31      18:11          Thursday  09-21-2023
# 143         12:17      13:49          Thursday  09-07-2023
# 144         13:45      16:17            Sunday  08-20-2023
# 145         00:00      18:40         Wednesday  06-07-2023
#
#                                         crime location  crime latitude  \
# 0                                   University Village       37.885668
# 1                                         2650 Haste S       37.866656
# 2                      on the 3100 Block of Dwight Way       37.866104
# 3                            Channing Way/ College Ave       37.867508
# 4                        Clark Kerr Campus building 23       37.864847
# ..                                                 ...             ...
# 141                                        Sproul Plaz       37.869693
# 142                                 1050 San Pablo Ave       37.886421
# 143                                       Stuart Stree       37.859870
# 144  Singletrack trail east of the Botanical Garden...       37.879508
# 145                             Richmond Field Station       37.912608
#
#      crime longitude crime day of week  total difference (in minutes)
# 0        -122.300929          Thursday                            113
# 1        -122.254336         Wednesday                            290
# 2        -122.249306           Tuesday                            216
# 3        -122.254250           Tuesday                            453
# 4        -122.247879          Thursday                             85
# ..               ...               ...                            ...
# 141      -122.259332         Wednesday                             44
# 142      -122.298131          Thursday                            400
# 143      -122.255850          Thursday                             92
# 144      -122.236161            Sunday                            152
# 145      -122.334430         Wednesday                           1120
#
# [146 rows x 12 columns]

# %%
difference = same_day_emails_df['total difference (in minutes)']
# same_day_emails.iloc[130] # change crime date to 05-03-2022..
# same_day_emails.iloc[36] # change crime date to 03-20-2022...
hullo = difference.to_list()
#np.mean((hullo)), np.std((hullo))**2
#np.percentile(hullo, 80)


import scipy.stats as stats
import matplotlib.pyplot as plt


# Scale parameter of ~ 1
blah = []
for i in hullo:
    blah = np.append(blah, i/164)

fit_alpha, fit_loc, fit_beta = stats.gamma.fit(hullo)
print(fit_alpha, fit_loc, fit_beta)

# r = alpha, lamba = beta

plt.figure(figsize=(10,5))
plt.xlim(0, 1440)
plt.xlabel('minutes')
plt.ylabel('freq')



# a = 5
sample = stats.gamma.rvs(1, loc=fit_loc , scale=fit_beta, size = 146)

sns.histplot(sample, bins = 30, kde = False)
sns.histplot(hullo, bins = 30, kde = False)
# sns.distplot((hullo),bins=30, kde=False)

# plt.show()
# np.mean(sample)
# Out:
# 0.9335043234030704 0.9999999999999998 178.49313585028733
# <Axes: xlabel='minutes', ylabel='freq'>

# %%
crimes_final_df[['crime latitude', 'crime longitude']]
# Out:
#      crime latitude  crime longitude
# 0         37.885668      -122.300929
# 1         37.866656      -122.254336
# 2         37.866104      -122.249306
# 3         37.867508      -122.254250
# 4         37.864847      -122.247879
# ..              ...              ...
# 172       37.871717      -122.252217
# 173       37.868045      -122.266886
# 174    -9999.000000     -9999.000000
# 175       37.865901      -122.255375
# 176       37.875068      -122.259883
#
# [177 rows x 2 columns]

# %%
crime_location_df = crimes_final_df[crimes_final_df['crime latitude'] != -9999].reset_index(drop = True)
crime_location_df

#crime_location_df filters out all crimes that don't have a location, which I manually inputted these with coordinates [-9999, -9999]
# Out:
#                                                Subject  \
# 0         Burglary at University Village: Albany (UVA)
# 1    Arson Reported at 2650 Haste St., Berkeley CA ...
# 2    Violent Crime Reported at 3100 Block of Dwight...
# 3    Violent Crime Reported at Channing Way/ Colleg...
# 4            Burglary at Clark Kerr Campus building 23
# ..                                                 ...
# 170            Burglary at 2521 Channing Way, Berkeley
# 171  Violent Crime Reported at Memorial Stadium - P...
# 172                        Burglary at Banway Building
# 173  Burglary at Unit 2 - Ehrman Hall, 2650 Haste S...
# 174                         Burglary at Northgate Hall
#
#                                                   Body date of crime  \
# 0     <https://oem.berkeley.edu/sites/default/files...    06-17-2021
# 1     <https://oem.berkeley.edu/sites/default/files...    06-16-2021
# 2     <https://oem.berkeley.edu/sites/default/files...    06-08-2021
# 3     <https://oem.berkeley.edu/sites/default/files...    05-18-2021
# 4     <https://oem.berkeley.edu/sites/default/files...    07-01-2021
# ..                                                 ...           ...
# 170   <https://oem.berkeley.edu/sites/default/files...    12-09-2022
# 171   <https://oem.berkeley.edu/sites/default/files...    04-08-2023
# 172   <https://oem.berkeley.edu/sites/default/files...    11-29-2023
# 173   <https://oem.berkeley.edu/sites/default/files...    07-07-2023
# 174   <https://oem.berkeley.edu/sites/default/files...    07-22-2023
#
#     time of crime email time email day of week  email date  \
# 0           02:09      04:02          Thursday  06-17-2021
# 1           05:20      10:10         Wednesday  06-16-2021
# 2           13:15      16:51           Tuesday  06-08-2021
# 3           15:50      23:23           Tuesday  05-18-2021
# 4           18:07      19:32          Thursday  07-01-2021
# ..            ...        ...               ...         ...
# 170         20:00      16:48            Monday  12-12-2022
# 171         17:40      06:25           Tuesday  04-11-2023
# 172         20:05      11:16            Friday  12-01-2023
# 173         22:00      17:15            Monday  07-10-2023
# 174         04:00      05:42            Monday  07-24-2023
#
#                                     crime location  crime latitude  \
# 0                               University Village       37.885668
# 1                                     2650 Haste S       37.866656
# 2                  on the 3100 Block of Dwight Way       37.866104
# 3                        Channing Way/ College Ave       37.867508
# 4                    Clark Kerr Campus building 23       37.864847
# ..                                             ...             ...
# 170                    2521 Channing Way, Berkeley       37.867461
# 171                               Memorial Stadium       37.871717
# 172                                Banway Building       37.868045
# 173  Unit 2 - Ehrman Hall, 2650 Haste St, Berkeley       37.865901
# 174                                 Northgate Hall       37.875068
#
#      crime longitude crime day of week  total difference (in minutes)
# 0        -122.300929          Thursday                            113
# 1        -122.254336         Wednesday                            290
# 2        -122.249306           Tuesday                            216
# 3        -122.254250           Tuesday                            453
# 4        -122.247879          Thursday                             85
# ..               ...               ...                            ...
# 170      -122.257944            Friday                           4128
# 171      -122.252217          Saturday                           3645
# 172      -122.266886         Wednesday                           2531
# 173      -122.255375            Friday                           4035
# 174      -122.259883          Saturday                           2982
#
# [175 rows x 12 columns]

# %%
num_rows = crime_location_df.shape[0]
location_arr = []
for i in range(num_rows):
   location_arr.append([crime_location_df.loc[i, 'crime latitude'], crime_location_df.loc[i, 'crime longitude']] )

#location_arr

# %%
folium_map = fol.Map(location=[37.871666, -122.272781], zoom_start = 12)
HeatMap(location_arr, overlay=True, fill_opacity=1, radius=10).add_to(folium_map)
folium_map
#crimes_final_df.groupby(by="crime day of week").count()
#crimes_final_df
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_82bb8299b89c60b34575bb3877ddb3e0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_82bb8299b89c60b34575bb3877ddb3e0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_82bb8299b89c60b34575bb3877ddb3e0 = L.map(
#                 &quot;map_82bb8299b89c60b34575bb3877ddb3e0&quot;,
#                 {
#                     center: [37.871666, -122.272781],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9c064d1b23099115eb107976bf871606 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9c064d1b23099115eb107976bf871606.addTo(map_82bb8299b89c60b34575bb3877ddb3e0);
#
#
#             var heat_map_e59c2bb33b08d46e56c42f7a36d04be6 = L.heatLayer(
#                 [[37.88566837488919, -122.30092909940954], [37.86665552582794, -122.25433591851044], [37.86610424037988, -122.2493061605156], [37.86750795125447, -122.25424953285788], [37.86484677848779, -122.24787866459457], [37.87609356106545, -122.26538185462118], [37.87202007014124, -122.26564447956429], [37.87060293649298, -122.2659985855477], [37.86781820643444, -122.25899259480302], [37.865573737486194, -122.2552224541243], [37.8676197535622, -122.26122597056194], [37.86953204164864, -122.2622653491982], [37.91363009321955, -122.33410994155716], [37.86648324936755, -122.2571126028434], [37.87379032049858, -122.2575404586629], [37.86304746489007, -122.26039073211932], [37.87081245854583, -122.26439206816865], [37.8709652765156, -122.26406951208769], [37.86751753675671, -122.25422736768546], [37.870701614199135, -122.2634021295405], [37.866889318488994, -122.25761943167934], [37.872468217709525, -122.24174801954294], [37.86968370594719, -122.26033123929126], [37.86575686025478, -122.26055330099094], [37.86993759383597, -122.25538785290266], [37.87090307843082, -122.25696504174218], [37.88329267537631, -122.30385400870256], [37.8682433312342, -122.25964613385412], [37.869317860271806, -122.26049723048824], [37.86540767127886, -122.25706234887276], [37.87344193583443, -122.25766334339797], [37.88723282268444, -122.3008877272338], [37.86892845206356, -122.25952183200177], [37.866020406494194, -122.26264597624498], [37.865867865204414, -122.25922951679873], [37.86570712975303, -122.2567912111524], [37.86433109076116, -122.2489114626912], [37.870444, -122.262111], [37.883228, -122.298581], [37.867962, -122.259649], [37.87186380964017, -122.25332804517107], [37.87619204598824, -122.258799245171], [37.86419416328994, -122.25025548521587], [37.87071141640448, -122.26344228778416], [37.867034978722415, -122.2588147740073], [37.87158379172142, -122.2599802149642], [37.8683466159758, -122.25129814517132], [37.88524254987419, -122.30029760501414], [37.87049105782291, -122.25387188375312], [37.87004422718286, -122.26180770284331], [37.88380869602941, -122.29852230946554], [37.86973034940577, -122.25986476345292], [37.8710081955918, -122.26299873167928], [37.872331713425964, -122.24649307432888], [37.8666921074396, -122.25751044517123], [37.87318023633792, -122.263000687499], [37.868201604696544, -122.25875756083802], [37.8727524847917, -122.2553643605152], [37.866092439082806, -122.2584790642201], [37.86593749636556, -122.25842481270622], [37.86180331529041, -122.25364233078508], [37.87273993929719, -122.2652156298268], [37.86639555739679, -122.2631812107783], [37.87596514184489, -122.25686640922834], [37.88455732220688, -122.30562416083409], [37.8663721112481, -122.25644555126098], [37.86597655316712, -122.25737250751231], [37.86871708273302, -122.25914892188258], [37.86660751287279, -122.25524021851058], [37.86554543619386, -122.25519676739856], [37.86723308823183, -122.26348801154208], [37.8752348819203, -122.2588586595714], [37.86802007110562, -122.25761770316596], [37.86920379879727, -122.26023414854107], [37.86756130823999, -122.25730043167944], [37.8677283085401, -122.26130452441932], [37.872201101493374, -122.24721644263906], [37.86825249462096, -122.25878973167934], [37.87159745345414, -122.25760696404691], [37.86382725604944, -122.24990127169713], [37.865744392794255, -122.25392575641256], [37.86814690102153, -122.2562641107314], [37.86672335637935, -122.2543788181876], [37.87151683374015, -122.25916926051542], [37.8669062580087, -122.25760870284331], [37.86780427942245, -122.25520381864958], [37.86605863119275, -122.25484788202176], [37.88539741113053, -122.300800353377], [37.87040285117511, -122.2595467893515], [37.86975380523294, -122.26027897432952], [37.87551680073064, -122.25628656877228], [37.871589210384336, -122.25751870284331], [37.874321424162765, -122.26533890574552], [37.87169685950271, -122.263824971164

# %%
# tester = crime_location_df[['crime day of week','Body']].groupby(by = "crime day of week").count().reset_index()
# sns.barplot(data = tester, x = 'crime day of week', y = 'Body')

#visualization idea: crime day trend, month trend?, time trend

# time_of_crime_s = crime_location_df[['time of crime']]
# crime_times_list = crime_location_df['time of crime']
# time_int_list = []

# for i in crime_times_list:
#     converted_hour = int(i[0:2])
#     converted_minute = int(i[3:5])/60 # to hours
#     time_in_int = converted_hour + converted_minute
#     time_int_list.append(time_in_int)

# hour_bins = np.arange(0, 25, 1)
# time_of_crime_s['times of crime (decimal)'] = time_int_list
# sns.histplot(time_int_list, bins = hour_bins)

crimes_map = fol.Map(location=[37.871666, -122.272781], zoom_start = 12)
loc_arr_length = range(len(location_arr))
[(fol.Marker(list(location_arr[c]), popup = "crime time: " + crime_location_df.loc[c, 'time of crime'] +'\n hello', 
             tooltip = crime_location_df.loc[c, 'Subject']).add_to(crimes_map)) for c in loc_arr_length]

crimes_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_97502408a27592726365d846db08abef {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_97502408a27592726365d846db08abef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_97502408a27592726365d846db08abef = L.map(
#                 &quot;map_97502408a27592726365d846db08abef&quot;,
#                 {
#                     center: [37.871666, -122.272781],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_52067726da51d50c4166d00743cb6abe = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_52067726da51d50c4166d00743cb6abe.addTo(map_97502408a27592726365d846db08abef);
#
#
#             var marker_6f60ea487080ef0258ea9f5c280cf099 = L.marker(
#                 [37.88566837488919, -122.30092909940954],
#                 {
# }
#             ).addTo(map_97502408a27592726365d846db08abef);
#
#
#         var popup_24b3963f37233e9803b6e3c81de46c24 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d22e79462888da2e1079aaa2f05f057d = $(`&lt;div id=&quot;html_d22e79462888da2e1079aaa2f05f057d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;crime time: 02:09  hello&lt;/div&gt;`)[0];
#                 popup_24b3963f37233e9803b6e3c81de46c24.setContent(html_d22e79462888da2e1079aaa2f05f057d);
#
#
#
#         marker_6f60ea487080ef0258ea9f5c280cf099.bindPopup(popup_24b3963f37233e9803b6e3c81de46c24)
#         ;
#
#
#
#
#             marker_6f60ea487080ef0258ea9f5c280cf099.bindTooltip(
#                 `&lt;div&gt;
#                      Burglary at University Village: Albany (UVA)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_e39f0fd47afd662c4b7b143198401d79 = L.marker(
#                 [37.86665552582794, -122.25433591851044],
#                 {
# }
#             ).addTo(map_97502408a27592726365d846db08abef);
#
#
#         var popup_a076d227c8bd962758a7a92914e2e172 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_69423ae6b857b07e129ca34d72865f51 = $(`&lt;div id=&quot;html_69423ae6b857b07e129ca34d72865f51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;crime time: 05:20  hello&lt;/div&gt;`)[0];
#                 popup_a076d227c8bd962758a7a92914e2e172.setContent(html_69423ae6b857b07e129ca34d72865f51);
#
#
#
#         marker_e39f0fd47afd662c4b7b143198401d79.bindPopup(popup_a076d227c8bd962758a7a92914e2e172)
#         ;
#
#
#
#
#             marker_e39f0fd47afd662c4b7b143198401d79.bindTooltip(
#                 `&lt;div&gt;
#                      Arson Reported at 2650 Haste St., Berkeley CA (Unit II central building) - Please note this message may contain information that some may find upsetting.
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_7a384820b487f34841f30cb4a68053b0 = L.marker(
#                 [37.86610424037988, -122.2493061605156],
#                 {
# }
#             ).addTo(map_97502408a27592726365d846db08abef);
#
#
#         var popup_7864080bb1176b301d7c36ebcb35ef35 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cce2409a56e37670b55387ab56120398 = $(`&lt;div id=&quot;html_cce2409a56e37670b55387ab56120398&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;crime time: 13:15  hello&lt;/div&gt;`)[0];
#                 popup_7864080bb1176b301d7c36ebcb35ef35.setContent(html_cce2409a56e37670b55387ab56120398);
#
#
#
#         marker_7a384820b487f34841f30cb4a68053b0.bindPopup(popup_7864080bb1176b301d7c36ebcb35ef35)
#         ;
#
#
#
#
#             marker_7a384820b487f34841f30cb4a68053b0.bindTooltip(
#                 `&lt;div&gt;
#                      Violent Crime Reported at 3100 Block of Dwight Way (next to Clark Kerr Campus) - Please note this message may contain information that some may find upsetting.
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_c7234196b53c69f1db7829e17473097d = L.marker(
#                 [37.86750795125447, -122.25424953285788],
#                 {
# }
#             ).addTo(map_97502408a27592726365d846db08abef);
#
#
#         var popup_e6e60dec41d5a26f36d3f7306c54b7bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9efaa03d34846bff9569fd8293192d3e = $(`&lt;div id=&quot;html_9efaa03d34846bff9569fd8293192d3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;crime time: 15:50  hello&lt;/div&gt;`)[0];
#                 popup_e6e60dec
